# %% [markdown]
# # MMD 2024, Collaborative Filtering on Google Colab
# This notebook sets up the enviroment and runs CF experiments on Google Colab.

# %%
# Import the repository code
import sys
#sys.path.insert(0,f"/content/{project}")

import data_util as cfd

# After edits of cf_algorithms_to_complete.py:
# 1. Rename the file rec_sys.cf_algorithms_to_complete.py to rec_sys.cf_algorithms.py
# 2. Restart the runtime (Runtime -> Restart the session); possibly not needed
# 3. Swap the comments in the next two lines, so that cf_algorithms is imported as cfa
import cf_algorithms_to_complete as cfa
#import rec_sys.cf_algorithms as cfa
# 4. Re-run all cells
# 5. If your changes are correct, you will see a long
#    printout of recommendations for MovieLens dataset (last cell)

# %%
# Load or set the configuration
#from rec_sys.cf_config import config

import dataclasses
@dataclasses.dataclass
class config:
    max_rows: int = int(1e5)
    dowload_url: str = "https://files.grouplens.org/datasets/movielens/ml-25m.zip"
    download_dir: str = "./data/"
    unzipped_dir: str = download_dir + "ml-25m/"
    file_path: str = download_dir + "ml-25m/ratings.csv"

# %%
# Load the MovieLens and Lecture datasets
um_movielens = cfd.get_um_by_name(config, "movielens")
um_lecture = cfd.get_um_by_name(config, "lecture_1")

# Rate all items for the lecture toy dataset
all_ratings = cfa.rate_all_items(um_lecture, 4, 2)
print ("all_ratings lecture toy dataset:", all_ratings)

# Rate all items the MovieLens data
all_ratings_movielens = cfa.rate_all_items(um_movielens, 0, 2)
print("all_ratings_movielens:", all_ratings_movielens)
# Out:
# Dir './data/ml-25m/' already exists, skipping download
#
# ### Start reading data from './data/ml-25m/ratings.csv'
# Loaded data from './data/ml-25m/ratings.csv', df shape: (100000, 3), size in MB: 1.1444091796875
# Pivoting the data
# Utility matrix, df shape: (9786, 757), size in MB: 29.142929077148438
# Final utility matrix (numpy array as np.float32), df shape: (9786, 757), size in MB: 28.25928497314453
#
# >>> CF computation for UM w/ shape: (6, 6), user_index: 4, neighborhood_size: 2
#
# sum_similarities: 0.0556951105215206, shape: ()
# bawr_similarities: [-0.15811388  0.21380899], shape: (2,)
# bawr_ratings_item: [5. 3.], shape: (2,)
# avg_rating_user: 0.0, shape: ()
# item_idx: 0, neighbors: [5 2], rating: nan
# sum_similarities: 0.7658614410038228, shape: ()
# bawr_similarities: [0.21380899 0.55205245], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: 0.0, shape: ()
# item_idx: 1, neighbors: [2 3], rating: nan
# all_ratings lecture toy dataset: [nan, nan, 2.0, 5.0, 4.0, 3.0]
#
# >>> CF computation for UM w/ shape: (9786, 757), user_index: 0, neighborhood_size: 2
#
# sum_similarities: 0.16170641779899597, shape: ()
# bawr_similarities: [0.0689483  0.09275813], shape: (2,)
# bawr_ratings_item: [1.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 70, neighbors: [645 420], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 71, neighbors: [439 755], rating: nan
# sum_similarities: 0.12788258492946625, shape: ()
# bawr_similarities: [0.06289994 0.06498265], shape: (2,)
# bawr_ratings_item: [3. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 72, neighbors: [ 37 678], rating: nan
# sum_similarities: 0.11766021698713303, shape: ()
# bawr_similarities: [0.05246729 0.06519293], shape: (2,)
# bawr_ratings_item: [3. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 73, neighbors: [201 355], rating: nan
# sum_similarities: 0.09768535196781158, shape: ()
# bawr_similarities: [0.04770995 0.0499754 ], shape: (2,)
# bawr_ratings_item: [2. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 74, neighbors: [612 216], rating: nan
# sum_similarities: 0.07471182942390442, shape: ()
# bawr_similarities: [0.02883262 0.04587922], shape: (2,)
# bawr_ratings_item: [4.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 75, neighbors: [105  11], rating: nan
# sum_similarities: 0.1556580662727356, shape: ()
# bawr_similarities: [0.06289994 0.09275813], shape: (2,)
# bawr_ratings_item: [4.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 76, neighbors: [ 37 420], rating: nan
# sum_similarities: 0.09514525532722473, shape: ()
# bawr_similarities: [0.04587922 0.04926604], shape: (2,)
# bawr_ratings_item: [3.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 77, neighbors: [ 11 565], rating: nan
# sum_similarities: 0.0972900316119194, shape: ()
# bawr_similarities: [0.048024   0.04926604], shape: (2,)
# bawr_ratings_item: [2. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 78, neighbors: [723 565], rating: nan
# sum_similarities: 0.11190169304609299, shape: ()
# bawr_similarities: [0.11190169], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 79, neighbors: [551], rating: nan
# sum_similarities: 0.14202415943145752, shape: ()
# bawr_similarities: [0.04926604 0.09275813], shape: (2,)
# bawr_ratings_item: [0.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 80, neighbors: [565 420], rating: nan
# sum_similarities: 0.11953224986791611, shape: ()
# bawr_similarities: [0.05433932 0.06519293], shape: (2,)
# bawr_ratings_item: [3. 1.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 81, neighbors: [456 355], rating: nan
# sum_similarities: 0.16170641779899597, shape: ()
# bawr_similarities: [0.0689483  0.09275813], shape: (2,)
# bawr_ratings_item: [3.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 82, neighbors: [645 420], rating: nan
# sum_similarities: 0.12361162900924683, shape: ()
# bawr_similarities: [0.05466333 0.0689483 ], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 83, neighbors: [755 645], rating: nan
# sum_similarities: 0.15795105695724487, shape: ()
# bawr_similarities: [0.06519293 0.09275813], shape: (2,)
# bawr_ratings_item: [1. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 84, neighbors: [355 420], rating: nan
# sum_similarities: 0.06519293040037155, shape: ()
# bawr_similarities: [0.06519293], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 85, neighbors: [355], rating: nan
# sum_similarities: 0.16170641779899597, shape: ()
# bawr_similarities: [0.0689483  0.09275813], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 86, neighbors: [645 420], rating: nan
# sum_similarities: 0.099078468978405, shape: ()
# bawr_similarities: [0.04587922 0.05319925], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 87, neighbors: [ 11 342], rating: nan
# sum_similarities: 0.09648977220058441, shape: ()
# bawr_similarities: [0.04587922 0.05061056], shape: (2,)
# bawr_ratings_item: [3.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 88, neighbors: [ 11 407], rating: nan
# sum_similarities: 0.12809287011623383, shape: ()
# bawr_similarities: [0.06289994 0.06519293], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 89, neighbors: [ 37 355], rating: nan
# sum_similarities: 0.07955177128314972, shape: ()
# bawr_similarities: [0.03933324 0.04021852], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 90, neighbors: [119 284], rating: nan
# sum_similarities: 0.0972900316119194, shape: ()
# bawr_similarities: [0.048024   0.04926604], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 91, neighbors: [723 565], rating: nan
# sum_similarities: 0.13201525807380676, shape: ()
# bawr_similarities: [0.06519293 0.06682234], shape: (2,)
# bawr_ratings_item: [1. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 92, neighbors: [355 732], rating: nan
# sum_similarities: 0.15795105695724487, shape: ()
# bawr_similarities: [0.06519293 0.09275813], shape: (2,)
# bawr_ratings_item: [2. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 93, neighbors: [355 420], rating: nan
# sum_similarities: 0.102498859167099, shape: ()
# bawr_similarities: [0.04783552 0.05466333], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 94, neighbors: [309 755], rating: nan
# sum_similarities: 0.11889131367206573, shape: ()
# bawr_similarities: [0.05390867 0.06498265], shape: (2,)
# bawr_ratings_item: [2.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 95, neighbors: [300 678], rating: nan
# sum_similarities: 0.18084999918937683, shape: ()
# bawr_similarities: [0.0689483  0.11190169], shape: (2,)
# bawr_ratings_item: [3.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 96, neighbors: [645 551], rating: nan
# sum_similarities: 0.10049614310264587, shape: ()
# bawr_similarities: [0.04926604 0.0512301 ], shape: (2,)
# bawr_ratings_item: [2.5 4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 97, neighbors: [565 439], rating: nan
# sum_similarities: 0.09120362997055054, shape: ()
# bawr_similarities: [0.04059307 0.05061056], shape: (2,)
# bawr_ratings_item: [5.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 98, neighbors: [425 407], rating: nan
# sum_similarities: 0.09794342517852783, shape: ()
# bawr_similarities: [0.04867738 0.04926604], shape: (2,)
# bawr_ratings_item: [5. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 99, neighbors: [ 97 565], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [5.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 100, neighbors: [755  37], rating: nan
# sum_similarities: 0.18400010466575623, shape: ()
# bawr_similarities: [0.09124198 0.09275813], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 101, neighbors: [521 420], rating: nan
# sum_similarities: 0.1556580662727356, shape: ()
# bawr_similarities: [0.06289994 0.09275813], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 102, neighbors: [ 37 420], rating: nan
# sum_similarities: 0.1556580662727356, shape: ()
# bawr_similarities: [0.06289994 0.09275813], shape: (2,)
# bawr_ratings_item: [2.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 103, neighbors: [ 37 420], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 104, neighbors: [755  37], rating: nan
# sum_similarities: 0.14590531587600708, shape: ()
# bawr_similarities: [0.05466333 0.09124198], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 105, neighbors: [755 521], rating: nan
# sum_similarities: 0.1474214643239975, shape: ()
# bawr_similarities: [0.05466333 0.09275813], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 106, neighbors: [755 420], rating: nan
# sum_similarities: 0.10857200622558594, shape: ()
# bawr_similarities: [0.05390867 0.05466333], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 107, neighbors: [300 755], rating: nan
# sum_similarities: 0.14202415943145752, shape: ()
# bawr_similarities: [0.04926604 0.09275813], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 108, neighbors: [565 420], rating: nan
# sum_similarities: 0.2046598196029663, shape: ()
# bawr_similarities: [0.09275813 0.11190169], shape: (2,)
# bawr_ratings_item: [5.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 109, neighbors: [420 551], rating: nan
# sum_similarities: 0.09514525532722473, shape: ()
# bawr_similarities: [0.04587922 0.04926604], shape: (2,)
# bawr_ratings_item: [4. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 110, neighbors: [ 11 565], rating: nan
# sum_similarities: 0.08081158995628357, shape: ()
# bawr_similarities: [0.04021852 0.04059307], shape: (2,)
# bawr_ratings_item: [5. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 111, neighbors: [284 425], rating: nan
# sum_similarities: 0.07860498130321503, shape: ()
# bawr_similarities: [0.03838645 0.04021852], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 112, neighbors: [546 284], rating: nan
# sum_similarities: 0.09758836776018143, shape: ()
# bawr_similarities: [0.04635826 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 113, neighbors: [266 439], rating: nan
# sum_similarities: 0.06289993971586227, shape: ()
# bawr_similarities: [0.06289994], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 114, neighbors: [37], rating: nan
# sum_similarities: 0.09562429785728455, shape: ()
# bawr_similarities: [0.04635826 0.04926604], shape: (2,)
# bawr_ratings_item: [3.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 115, neighbors: [266 565], rating: nan
# sum_similarities: 0.09056846797466278, shape: ()
# bawr_similarities: [0.04059307 0.0499754 ], shape: (2,)
# bawr_ratings_item: [4.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 116, neighbors: [425 216], rating: nan
# sum_similarities: 0.08642885088920593, shape: ()
# bawr_similarities: [0.04059307 0.04583579], shape: (2,)
# bawr_ratings_item: [1. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 117, neighbors: [425 237], rating: nan
# sum_similarities: 0.10786259174346924, shape: ()
# bawr_similarities: [0.05319925 0.05466333], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 118, neighbors: [342 755], rating: nan
# sum_similarities: 0.10786259174346924, shape: ()
# bawr_similarities: [0.05319925 0.05466333], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 119, neighbors: [342 755], rating: nan
# sum_similarities: 0.10786259174346924, shape: ()
# bawr_similarities: [0.05319925 0.05466333], shape: (2,)
# bawr_ratings_item: [4.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 120, neighbors: [342 755], rating: nan
# sum_similarities: 0.10184065997600555, shape: ()
# bawr_similarities: [0.05061056 0.0512301 ], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 121, neighbors: [407 439], rating: nan
# sum_similarities: 0.07433377951383591, shape: ()
# bawr_similarities: [0.03317872 0.04115506], shape: (2,)
# bawr_ratings_item: [0.5 1. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 122, neighbors: [430 225], rating: nan
# sum_similarities: 0.009263248182833195, shape: ()
# bawr_similarities: [0.00059581 0.00866744], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 123, neighbors: [413 395], rating: nan
# sum_similarities: 0.1439882218837738, shape: ()
# bawr_similarities: [0.0512301  0.09275813], shape: (2,)
# bawr_ratings_item: [2. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 124, neighbors: [439 420], rating: nan
# sum_similarities: 0.05848296731710434, shape: ()
# bawr_similarities: [0.02316628 0.03531669], shape: (2,)
# bawr_ratings_item: [3.5 1. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 125, neighbors: [547  79], rating: nan
# sum_similarities: 0.11964598298072815, shape: ()
# bawr_similarities: [0.05466333 0.06498265], shape: (2,)
# bawr_ratings_item: [4.5 2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 126, neighbors: [755 678], rating: nan
# sum_similarities: 0.16170641779899597, shape: ()
# bawr_similarities: [0.0689483  0.09275813], shape: (2,)
# bawr_ratings_item: [1.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 127, neighbors: [645 420], rating: nan
# sum_similarities: 0.1474214643239975, shape: ()
# bawr_similarities: [0.05466333 0.09275813], shape: (2,)
# bawr_ratings_item: [3.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 128, neighbors: [755 420], rating: nan
# sum_similarities: 0.10388407111167908, shape: ()
# bawr_similarities: [0.0499754  0.05390867], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 129, neighbors: [216 300], rating: nan
# sum_similarities: 0.10317465662956238, shape: ()
# bawr_similarities: [0.0499754  0.05319925], shape: (2,)
# bawr_ratings_item: [4.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 130, neighbors: [216 342], rating: nan
# sum_similarities: 0.08081158995628357, shape: ()
# bawr_similarities: [0.04021852 0.04059307], shape: (2,)
# bawr_ratings_item: [4. 1.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 131, neighbors: [284 425], rating: nan
# sum_similarities: 0.08429360389709473, shape: ()
# bawr_similarities: [0.04059307 0.04370053], shape: (2,)
# bawr_ratings_item: [3.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 132, neighbors: [425 317], rating: nan
# sum_similarities: 0.10857200622558594, shape: ()
# bawr_similarities: [0.05390867 0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 133, neighbors: [300 755], rating: nan
# sum_similarities: 0.09585461020469666, shape: ()
# bawr_similarities: [0.04587922 0.0499754 ], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 134, neighbors: [ 11 216], rating: nan
# sum_similarities: 0.1618770956993103, shape: ()
# bawr_similarities: [0.0499754  0.11190169], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 135, neighbors: [216 551], rating: nan
# sum_similarities: 0.08081158995628357, shape: ()
# bawr_similarities: [0.04021852 0.04059307], shape: (2,)
# bawr_ratings_item: [4.  0.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 136, neighbors: [284 425], rating: nan
# sum_similarities: 0.11679773032665253, shape: ()
# bawr_similarities: [0.0499754  0.06682234], shape: (2,)
# bawr_ratings_item: [3.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 137, neighbors: [216 732], rating: nan
# sum_similarities: 0.10786259174346924, shape: ()
# bawr_similarities: [0.05319925 0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 138, neighbors: [342 755], rating: nan
# sum_similarities: 0.08898429572582245, shape: ()
# bawr_similarities: [0.04059307 0.04839123], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 139, neighbors: [425  69], rating: nan
# sum_similarities: 0.14488768577575684, shape: ()
# bawr_similarities: [0.05212956 0.09275813], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 140, neighbors: [207 420], rating: nan
# sum_similarities: 0.1787240207195282, shape: ()
# bawr_similarities: [0.06682234 0.11190169], shape: (2,)
# bawr_ratings_item: [5.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 141, neighbors: [732 551], rating: nan
# sum_similarities: 0.11679773032665253, shape: ()
# bawr_similarities: [0.0499754  0.06682234], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 142, neighbors: [216 732], rating: nan
# sum_similarities: 0.09514525532722473, shape: ()
# bawr_similarities: [0.04587922 0.04926604], shape: (2,)
# bawr_ratings_item: [2. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 143, neighbors: [ 11 565], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 144, neighbors: [439 755], rating: nan
# sum_similarities: 0.08966226875782013, shape: ()
# bawr_similarities: [0.03843217 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 145, neighbors: [170 439], rating: nan
# sum_similarities: 0.0905633419752121, shape: ()
# bawr_similarities: [0.03933324 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 146, neighbors: [119 439], rating: nan
# sum_similarities: 0.10246528685092926, shape: ()
# bawr_similarities: [0.04926604 0.05319925], shape: (2,)
# bawr_ratings_item: [5.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 147, neighbors: [565 342], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 148, neighbors: [439 755], rating: nan
# sum_similarities: 0.11823610216379166, shape: ()
# bawr_similarities: [0.0512301 0.067006 ], shape: (2,)
# bawr_ratings_item: [4. 1.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 149, neighbors: [439 271], rating: nan
# sum_similarities: 0.09307853877544403, shape: ()
# bawr_similarities: [0.04381251 0.04926604], shape: (2,)
# bawr_ratings_item: [2.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 150, neighbors: [ 18 565], rating: nan
# sum_similarities: 0.10054254531860352, shape: ()
# bawr_similarities: [0.04587922 0.05466333], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 151, neighbors: [ 11 755], rating: nan
# sum_similarities: 0.11561262607574463, shape: ()
# bawr_similarities: [0.05271269 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 152, neighbors: [488  37], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 153, neighbors: [439 755], rating: nan
# sum_similarities: 0.0936739593744278, shape: ()
# bawr_similarities: [0.04440792 0.04926604], shape: (2,)
# bawr_ratings_item: [5. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 154, neighbors: [331 565], rating: nan
# sum_similarities: 0.09514525532722473, shape: ()
# bawr_similarities: [0.04587922 0.04926604], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 155, neighbors: [ 11 565], rating: nan
# sum_similarities: 0.09296657145023346, shape: ()
# bawr_similarities: [0.04370053 0.04926604], shape: (2,)
# bawr_ratings_item: [3.  1.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 156, neighbors: [317 565], rating: nan
# sum_similarities: 0.057168520987033844, shape: ()
# bawr_similarities: [0.02398979 0.03317872], shape: (2,)
# bawr_ratings_item: [2. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 157, neighbors: [215 430], rating: nan
# /home/fynn/Scientific Computing/Mining Massive Datasets/24WS-mmd-code-public/rec_sys/cf_algorithms_to_complete.py:30: RuntimeWarning: invalid value encountered in divide
#   um_normalized = utility_matrix / norms
# sum_similarities: 0.0894845575094223, shape: ()
# bawr_similarities: [0.04021852 0.04926604], shape: (2,)
# bawr_ratings_item: [5.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 158, neighbors: [284 565], rating: nan
# sum_similarities: 0.2031436711549759, shape: ()
# bawr_similarities: [0.09124198 0.11190169], shape: (2,)
# bawr_ratings_item: [4.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 159, neighbors: [521 551], rating: nan
# sum_similarities: 0.10049614310264587, shape: ()
# bawr_similarities: [0.04926604 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 160, neighbors: [565 439], rating: nan
# sum_similarities: 0.10737602412700653, shape: ()
# bawr_similarities: [0.05271269 0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 161, neighbors: [488 755], rating: nan
# sum_similarities: 0.07464993000030518, shape: ()
# bawr_similarities: [0.03531669 0.03933324], shape: (2,)
# bawr_ratings_item: [1. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 162, neighbors: [ 79 119], rating: nan
# sum_similarities: 0.11335621774196625, shape: ()
# bawr_similarities: [0.04440792 0.0689483 ], shape: (2,)
# bawr_ratings_item: [1. 1.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 163, neighbors: [331 645], rating: nan
# sum_similarities: 0.06632202863693237, shape: ()
# bawr_similarities: [0.032129   0.03419303], shape: (2,)
# bawr_ratings_item: [1.  1.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 164, neighbors: [177 193], rating: nan
# sum_similarities: 0.0939965769648552, shape: ()
# bawr_similarities: [0.03933324 0.05466333], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 165, neighbors: [119 755], rating: nan
# sum_similarities: 0.07958722114562988, shape: ()
# bawr_similarities: [0.03843217 0.04115506], shape: (2,)
# bawr_ratings_item: [3.5 2. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 166, neighbors: [170 225], rating: nan
# sum_similarities: 0.17480163276195526, shape: ()
# bawr_similarities: [0.06289994 0.11190169], shape: (2,)
# bawr_ratings_item: [4.5 2. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 167, neighbors: [ 37 551], rating: nan
# sum_similarities: 0.10184065997600555, shape: ()
# bawr_similarities: [0.05061056 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 168, neighbors: [407 439], rating: nan
# sum_similarities: 0.1067928895354271, shape: ()
# bawr_similarities: [0.05212956 0.05466333], shape: (2,)
# bawr_ratings_item: [4.5 1. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 169, neighbors: [207 755], rating: nan
# sum_similarities: 0.10442935675382614, shape: ()
# bawr_similarities: [0.0512301  0.05319925], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 170, neighbors: [439 342], rating: nan
# sum_similarities: 0.0817481279373169, shape: ()
# bawr_similarities: [0.04059307 0.04115506], shape: (2,)
# bawr_ratings_item: [2. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 171, neighbors: [425 225], rating: nan
# sum_similarities: 0.086472287774086, shape: ()
# bawr_similarities: [0.04059307 0.04587922], shape: (2,)
# bawr_ratings_item: [3.5 2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 172, neighbors: [425  11], rating: nan
# sum_similarities: 0.09987659752368927, shape: ()
# bawr_similarities: [0.04926604 0.05061056], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 173, neighbors: [565 407], rating: nan
# sum_similarities: 0.10857200622558594, shape: ()
# bawr_similarities: [0.05390867 0.05466333], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 174, neighbors: [300 755], rating: nan
# sum_similarities: 0.10049614310264587, shape: ()
# bawr_similarities: [0.04926604 0.0512301 ], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 175, neighbors: [565 439], rating: nan
# sum_similarities: 0.10392937064170837, shape: ()
# bawr_similarities: [0.04926604 0.05466333], shape: (2,)
# bawr_ratings_item: [3.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 176, neighbors: [565 755], rating: nan
# sum_similarities: 0.09176561236381531, shape: ()
# bawr_similarities: [0.04115506 0.05061056], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 177, neighbors: [225 407], rating: nan
# sum_similarities: 0.09484419226646423, shape: ()
# bawr_similarities: [0.04587922 0.04896498], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 178, neighbors: [ 11 137], rating: nan
# sum_similarities: 0.03765396773815155, shape: ()
# bawr_similarities: [0.01501658 0.02263739], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 179, neighbors: [598 590], rating: nan
# sum_similarities: 0.08582878857851028, shape: ()
# bawr_similarities: [0.03656275 0.04926604], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 180, neighbors: [476 565], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 181, neighbors: [755  37], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 182, neighbors: [755  37], rating: nan
# sum_similarities: 0.014776884578168392, shape: ()
# bawr_similarities: [0.0003285  0.01444839], shape: (2,)
# bawr_ratings_item: [2.5 0.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 183, neighbors: [  1 188], rating: nan
# sum_similarities: 0.08081158995628357, shape: ()
# bawr_similarities: [0.04021852 0.04059307], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 184, neighbors: [284 425], rating: nan
# sum_similarities: 0.09962132573127747, shape: ()
# bawr_similarities: [0.04839123 0.0512301 ], shape: (2,)
# bawr_ratings_item: [2. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 185, neighbors: [ 69 439], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 186, neighbors: [439 755], rating: nan
# sum_similarities: 0.07464993000030518, shape: ()
# bawr_similarities: [0.03531669 0.03933324], shape: (2,)
# bawr_ratings_item: [2. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 187, neighbors: [ 79 119], rating: nan
# sum_similarities: 0.0817481279373169, shape: ()
# bawr_similarities: [0.04059307 0.04115506], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 188, neighbors: [425 225], rating: nan
# sum_similarities: 0.11413004249334335, shape: ()
# bawr_similarities: [0.0512301  0.06289994], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 189, neighbors: [439  37], rating: nan
# sum_similarities: 0.07075577974319458, shape: ()
# bawr_similarities: [0.03419303 0.03656275], shape: (2,)
# bawr_ratings_item: [0.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 190, neighbors: [193 476], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 191, neighbors: [439 755], rating: nan
# sum_similarities: 0.09832051396369934, shape: ()
# bawr_similarities: [0.04770995 0.05061056], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 192, neighbors: [612 407], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 193, neighbors: [755  37], rating: nan
# sum_similarities: 0.03466399759054184, shape: ()
# bawr_similarities: [0.00148527 0.03317872], shape: (2,)
# bawr_ratings_item: [3.5 2. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 194, neighbors: [652 430], rating: nan
# sum_similarities: 0.09710931777954102, shape: ()
# bawr_similarities: [0.04587922 0.0512301 ], shape: (2,)
# bawr_ratings_item: [4.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 195, neighbors: [ 11 439], rating: nan
# sum_similarities: 0.11561262607574463, shape: ()
# bawr_similarities: [0.05271269 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 196, neighbors: [488  37], rating: nan
# sum_similarities: 0.0936739593744278, shape: ()
# bawr_similarities: [0.04440792 0.04926604], shape: (2,)
# bawr_ratings_item: [4.5 5. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 197, neighbors: [331 565], rating: nan
# sum_similarities: 0.10737602412700653, shape: ()
# bawr_similarities: [0.05271269 0.05466333], shape: (2,)
# bawr_ratings_item: [5.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 198, neighbors: [488 755], rating: nan
# sum_similarities: 0.17480163276195526, shape: ()
# bawr_similarities: [0.06289994 0.11190169], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 199, neighbors: [ 37 551], rating: nan
# sum_similarities: 0.11744993180036545, shape: ()
# bawr_similarities: [0.05246729 0.06498265], shape: (2,)
# bawr_ratings_item: [2.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 200, neighbors: [201 678], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 201, neighbors: [755  37], rating: nan
# sum_similarities: 0.13393095135688782, shape: ()
# bawr_similarities: [0.06498265 0.0689483 ], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 202, neighbors: [678 645], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 203, neighbors: [755  37], rating: nan
# sum_similarities: 0.11561262607574463, shape: ()
# bawr_similarities: [0.05271269 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 204, neighbors: [488  37], rating: nan
# sum_similarities: 0.08703427016735077, shape: ()
# bawr_similarities: [0.04115506 0.04587922], shape: (2,)
# bawr_ratings_item: [3.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 205, neighbors: [225  11], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [3.5 2. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 206, neighbors: [755  37], rating: nan
# sum_similarities: 0.10737602412700653, shape: ()
# bawr_similarities: [0.05271269 0.05466333], shape: (2,)
# bawr_ratings_item: [4.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 207, neighbors: [488 755], rating: nan
# sum_similarities: 0.12788258492946625, shape: ()
# bawr_similarities: [0.06289994 0.06498265], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 208, neighbors: [ 37 678], rating: nan
# sum_similarities: 0.07070066034793854, shape: ()
# bawr_similarities: [0.03226849 0.03843217], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 209, neighbors: [607 170], rating: nan
# sum_similarities: 0.11964598298072815, shape: ()
# bawr_similarities: [0.05466333 0.06498265], shape: (2,)
# bawr_ratings_item: [3.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 210, neighbors: [755 678], rating: nan
# sum_similarities: 0.06869293004274368, shape: ()
# bawr_similarities: [0.03079177 0.03790117], shape: (2,)
# bawr_ratings_item: [3. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 211, neighbors: [154  83], rating: nan
# sum_similarities: 0.07345865666866302, shape: ()
# bawr_similarities: [0.02964615 0.04381251], shape: (2,)
# bawr_ratings_item: [4. 1.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 212, neighbors: [631  18], rating: nan
# sum_similarities: 0.07499492168426514, shape: ()
# bawr_similarities: [0.03656275 0.03843217], shape: (2,)
# bawr_ratings_item: [2.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 213, neighbors: [476 170], rating: nan
# sum_similarities: 0.09097002446651459, shape: ()
# bawr_similarities: [0.02807008 0.06289994], shape: (2,)
# bawr_ratings_item: [3. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 214, neighbors: [ 2 37], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [2.5 2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 215, neighbors: [439 755], rating: nan
# sum_similarities: 0.00032849604031071067, shape: ()
# bawr_similarities: [0.0003285], shape: (1,)
# bawr_ratings_item: [5.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 216, neighbors: [1], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 217, neighbors: [755  37], rating: nan
# sum_similarities: 0.07902523875236511, shape: ()
# bawr_similarities: [0.03843217 0.04059307], shape: (2,)
# bawr_ratings_item: [4.5 2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 218, neighbors: [170 425], rating: nan
# sum_similarities: 0.07646730542182922, shape: ()
# bawr_similarities: [0.01148466 0.06498265], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 219, neighbors: [ 12 678], rating: nan
# sum_similarities: 0.09309549629688263, shape: ()
# bawr_similarities: [0.03843217 0.05466333], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 220, neighbors: [170 755], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 221, neighbors: [755  37], rating: nan
# sum_similarities: 0.06892679631710052, shape: ()
# bawr_similarities: [0.03233174 0.03659505], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 222, neighbors: [549 713], rating: nan
# sum_similarities: 0.07377684116363525, shape: ()
# bawr_similarities: [0.02316628 0.05061056], shape: (2,)
# bawr_ratings_item: [4.  3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 223, neighbors: [547 407], rating: nan
# sum_similarities: 0.06112426146864891, shape: ()
# bawr_similarities: [0.01185822 0.04926604], shape: (2,)
# bawr_ratings_item: [5. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 224, neighbors: [711 565], rating: nan
# sum_similarities: 0.17480163276195526, shape: ()
# bawr_similarities: [0.06289994 0.11190169], shape: (2,)
# bawr_ratings_item: [2.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 225, neighbors: [ 37 551], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 226, neighbors: [755  37], rating: nan
# sum_similarities: 0.18084999918937683, shape: ()
# bawr_similarities: [0.0689483  0.11190169], shape: (2,)
# bawr_ratings_item: [2.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 227, neighbors: [645 551], rating: nan
# sum_similarities: 0.09182317554950714, shape: ()
# bawr_similarities: [0.04059307 0.0512301 ], shape: (2,)
# bawr_ratings_item: [2.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 228, neighbors: [425 439], rating: nan
# sum_similarities: 0.07212715595960617, shape: ()
# bawr_similarities: [0.03317872 0.03894843], shape: (2,)
# bawr_ratings_item: [3. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 229, neighbors: [430 500], rating: nan
# sum_similarities: 0.044029030948877335, shape: ()
# bawr_similarities: [0.0003285  0.04370053], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 230, neighbors: [  1 317], rating: nan
# sum_similarities: 0.04209718853235245, shape: ()
# bawr_similarities: [0.00366502 0.03843217], shape: (2,)
# bawr_ratings_item: [2.  4.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 231, neighbors: [741 170], rating: nan
# sum_similarities: 0.11818189918994904, shape: ()
# bawr_similarities: [0.05319925 0.06498265], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 232, neighbors: [342 678], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [3. 2.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 233, neighbors: [755  37], rating: nan
# sum_similarities: 0.1067928895354271, shape: ()
# bawr_similarities: [0.05212956 0.05466333], shape: (2,)
# bawr_ratings_item: [5.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 234, neighbors: [207 755], rating: nan
# sum_similarities: 0.07902523875236511, shape: ()
# bawr_similarities: [0.03843217 0.04059307], shape: (2,)
# bawr_ratings_item: [4.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 235, neighbors: [170 425], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [4.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 236, neighbors: [755  37], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [2.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 237, neighbors: [755  37], rating: nan
# sum_similarities: 0.052812427282333374, shape: ()
# bawr_similarities: [0.02316628 0.02964615], shape: (2,)
# bawr_ratings_item: [3.5 4. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 238, neighbors: [547 631], rating: nan
# sum_similarities: 0.15414191782474518, shape: ()
# bawr_similarities: [0.06289994 0.09124198], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 239, neighbors: [ 37 521], rating: nan
# sum_similarities: 0.00032849604031071067, shape: ()
# bawr_similarities: [0.0003285], shape: (1,)
# bawr_ratings_item: [0.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 240, neighbors: [1], rating: nan
# sum_similarities: 0.026629738509655, shape: ()
# bawr_similarities: [0.00850338 0.01812636], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 241, neighbors: [571 550], rating: nan
# sum_similarities: 0.11756327748298645, shape: ()
# bawr_similarities: [0.05466333 0.06289994], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 242, neighbors: [755  37], rating: nan
# sum_similarities: 0.10737602412700653, shape: ()
# bawr_similarities: [0.05271269 0.05466333], shape: (2,)
# bawr_ratings_item: [5. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 243, neighbors: [488 755], rating: nan
# sum_similarities: 0.061056382954120636, shape: ()
# bawr_similarities: [0.02046332 0.04059307], shape: (2,)
# bawr_ratings_item: [3.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 244, neighbors: [226 425], rating: nan
# sum_similarities: 0.12348031997680664, shape: ()
# bawr_similarities: [0.06058038 0.06289994], shape: (2,)
# bawr_ratings_item: [3.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 245, neighbors: [336  37], rating: nan
# sum_similarities: 0.10589343309402466, shape: ()
# bawr_similarities: [0.0512301  0.05466333], shape: (2,)
# bawr_ratings_item: [3.5 1.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 246, neighbors: [439 755], rating: nan
# sum_similarities: 0.11413004249334335, shape: ()
# bawr_similarities: [0.0512301  0.06289994], shape: (2,)
# bawr_ratings_item: [4.  2.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 247, neighbors: [439  37], rating: nan
# sum_similarities: 0.06686681509017944, shape: ()
# bawr_similarities: [0.02316628 0.04370053], shape: (2,)
# bawr_ratings_item: [3.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 248, neighbors: [547 317], rating: nan
# sum_similarities: 0.11372461915016174, shape: ()
# bawr_similarities: [0.04874197 0.06498265], shape: (2,)
# bawr_ratings_item: [4.5 3.5], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 249, neighbors: [686 678], rating: nan
# sum_similarities: 0.099078468978405, shape: ()
# bawr_similarities: [0.04587922 0.05319925], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 250, neighbors: [ 11 342], rating: nan
# sum_similarities: 0.18031007051467896, shape: ()
# bawr_similarities: [0.06840837 0.11190169], shape: (2,)
# bawr_ratings_item: [3. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 251, neighbors: [620 551], rating: nan
# sum_similarities: 0.17709462344646454, shape: ()
# bawr_similarities: [0.06519293 0.11190169], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 252, neighbors: [355 551], rating: nan
# sum_similarities: 0.12307170033454895, shape: ()
# bawr_similarities: [0.05466333 0.06840837], shape: (2,)
# bawr_ratings_item: [4. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 253, neighbors: [755 620], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 254, neighbors: [755], rating: nan
# sum_similarities: 0.08745318651199341, shape: ()
# bawr_similarities: [0.03942919 0.048024  ], shape: (2,)
# bawr_ratings_item: [3. 3.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 255, neighbors: [ 31 723], rating: nan
# sum_similarities: 0.08030644059181213, shape: ()
# bawr_similarities: [0.03824283 0.04206361], shape: (2,)
# bawr_ratings_item: [5. 5.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 256, neighbors: [341 687], rating: nan
# sum_similarities: 0.15824797749519348, shape: ()
# bawr_similarities: [0.067006   0.09124198], shape: (2,)
# bawr_ratings_item: [5. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 257, neighbors: [271 521], rating: nan
# sum_similarities: 0.10786259174346924, shape: ()
# bawr_similarities: [0.05319925 0.05466333], shape: (2,)
# bawr_ratings_item: [0.5 3. ], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 258, neighbors: [342 755], rating: nan
# sum_similarities: 0.1556580662727356, shape: ()
# bawr_similarities: [0.06289994 0.09275813], shape: (2,)
# bawr_ratings_item: [4. 4.], shape: (2,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 259, neighbors: [ 37 420], rating: nan
# sum_similarities: 0.06894829869270325, shape: ()
# bawr_similarities: [0.0689483], shape: (1,)
# ...
# item_idx: 9733, neighbors: [733], rating: nan
# sum_similarities: 0.014829163439571857, shape: ()
# bawr_similarities: [0.01482916], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9734, neighbors: [735], rating: nan
# sum_similarities: 0.014829163439571857, shape: ()
# bawr_similarities: [0.01482916], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9735, neighbors: [735], rating: nan
# sum_similarities: 0.014829163439571857, shape: ()
# bawr_similarities: [0.01482916], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9736, neighbors: [735], rating: nan
# sum_similarities: 0.014829163439571857, shape: ()
# bawr_similarities: [0.01482916], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9737, neighbors: [735], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9738, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9739, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9740, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [1.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9741, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9742, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9743, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9744, neighbors: [737], rating: nan
# sum_similarities: 0.01766875572502613, shape: ()
# bawr_similarities: [0.01766876], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9745, neighbors: [737], rating: nan
# sum_similarities: -0.014442498795688152, shape: ()
# bawr_similarities: [-0.0144425], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9746, neighbors: [739], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9747, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [5.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9748, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9749, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9750, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [2.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9751, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9752, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [5.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9753, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9754, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [2.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9755, neighbors: [740], rating: nan
# sum_similarities: -0.0030855019576847553, shape: ()
# bawr_similarities: [-0.0030855], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9756, neighbors: [740], rating: nan
# sum_similarities: 0.003665022552013397, shape: ()
# bawr_similarities: [0.00366502], shape: (1,)
# bawr_ratings_item: [0.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9757, neighbors: [741], rating: nan
# sum_similarities: -0.07795462012290955, shape: ()
# bawr_similarities: [-0.07795462], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9758, neighbors: [743], rating: nan
# sum_similarities: 0.006899894680827856, shape: ()
# bawr_similarities: [0.00689989], shape: (1,)
# bawr_ratings_item: [2.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9759, neighbors: [744], rating: nan
# sum_similarities: -0.023496810346841812, shape: ()
# bawr_similarities: [-0.02349681], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9760, neighbors: [745], rating: nan
# sum_similarities: 0.009449824690818787, shape: ()
# bawr_similarities: [0.00944982], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9761, neighbors: [747], rating: nan
# sum_similarities: 0.0060142045840620995, shape: ()
# bawr_similarities: [0.0060142], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9762, neighbors: [749], rating: nan
# sum_similarities: 0.0060142045840620995, shape: ()
# bawr_similarities: [0.0060142], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9763, neighbors: [749], rating: nan
# sum_similarities: 0.0, shape: ()
# bawr_similarities: [0.], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9764, neighbors: [750], rating: nan
# sum_similarities: -0.003736229380592704, shape: ()
# bawr_similarities: [-0.00373623], shape: (1,)
# bawr_ratings_item: [2.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9765, neighbors: [751], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [2.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9766, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [5.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9767, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [2.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9768, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9769, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [2.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9770, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9771, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9772, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9773, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [0.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9774, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [1.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9775, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [0.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9776, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [3.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9777, neighbors: [755], rating: nan
# sum_similarities: 0.05466333404183388, shape: ()
# bawr_similarities: [0.05466333], shape: (1,)
# bawr_ratings_item: [0.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9778, neighbors: [755], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9779, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9780, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9781, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [4.], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9782, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9783, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [3.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9784, neighbors: [756], rating: nan
# sum_similarities: 0.002931710099801421, shape: ()
# bawr_similarities: [0.00293171], shape: (1,)
# bawr_ratings_item: [4.5], shape: (1,)
# avg_rating_user: -2.923587760772506e-10, shape: ()
# item_idx: 9785, neighbors: [756], rating: nan
# all_ratings_movielens: [5.0, 3.5, 5.0, 5.0, 3.5, 4.0, 3.5, 3.5, 5.0, 4.0, 3.5, 4.0, 2.5, 2.5, 2.5, 3.5, 4.5, 4.0, 5.0, 5.0, 4.5, 4.0, 5.0, 5.0, 5.0, 3.0, 5.0, 3.0, 4.0, 4.5, 4.0, 0.5, 2.0, 5.0, 4.0, 3.0, 4.0, 5.0, 4.5, 4.0, 3.5, 5.0, 3.5, 4.0, 4.5, 2.0, 3.5, 3.5, 5.0, 4.0, 2.5, 3.0, 2.5, 2.5, 4.5, 3.5, 5.0, 5.0, 4.0, 3.5, 1.0, 3.5, 4.0, 3.0, 4.0, 3.0, 4.5, 3.0, 3.5, 5.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, n ...
